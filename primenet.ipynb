# %%
# !pip install stable-baselines3

# %%
import gymnasium as gym
import numpy as np
from gymnasium import spaces

# %%
class PrimeEnv(gym.Env):
    def __init__(self, max_bits=16):
        self.observation_space = spaces.MultiBinary(max_bits)
        self.action_space = spaces.MultiBinary(max_bits)
    
    def reset(self, **kwargs):
        start_state = self.observation_space.sample()
        self.state_ = start_state
        return start_state, {}
    
    def step(self, action):
        next_state = action
        next_state_decimal = self.binatodeci(next_state)
        done = False
        if next_state_decimal > self.binatodeci(self.state_):
            if self.is_prime(next_state_decimal):
                reward = 1
            else:
                reward = 0
        else:
            reward = 0
            done = True
        self.state_ = next_state
        return next_state, reward, done, False, {}
    
    def binatodeci(self, binary):
        return sum(val*(2**idx) for idx, val in enumerate(reversed(binary)))

    def is_prime(self, state):
        tmp_state = int(state)
        if tmp_state > 1:
        # Iterate from 2 to n // 2
            for i in range(2, (tmp_state//2)+1):
                # If num is divisible by any number between
                # 2 and n / 2, it is not prime
                if (tmp_state % i) == 0:
                    return 0
            else:
                return 1
        else:
            return 0

# %%
from stable_baselines3 import PPO
import torch as th

model = PPO("MlpPolicy", env = gym.wrappers.time_limit.TimeLimit(PrimeEnv(),100), verbose = 1)
model.learn(1e7)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.66     |
# |    ep_rew_mean     | 0.07     |
# | time/              |          |
# |    fps             | 1910     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.84        |
# |    ep_rew_mean          | 0.11        |
# | time/                   |             |
# |    fps                  | 1468        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012947267 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.1       |
# |    explained_variance   | -1.73       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0273     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0298     |
# |    value_loss           | 0.064       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72        |
# |    ep_rew_mean          | 0.08        |
# | time/                   |             |
# |    fps                  | 1361        |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.012796984 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.1       |
# |    explained_variance   | -0.00874    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.034      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0325     |
# |    value_loss           | 0.0537      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.81        |
# |    ep_rew_mean          | 0.06        |
# | time/                   |             |
# |    fps                  | 1310        |
# |    iterations           | 4           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.015013226 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11         |
# |    explained_variance   | -0.00899    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00254     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0342     |
# |    value_loss           | 0.0603      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.72       |
# |    ep_rew_mean          | 0.08       |
# | time/                   |            |
# |    fps                  | 1284       |
# |    iterations           | 5          |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.01464526 |
# |    clip_fraction        | 0.206      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -11        |
# |    explained_variance   | 0.023      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0169    |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.034     |
# |    value_loss           | 0.0669     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99        |
# |    ep_rew_mean          | 0.15        |
# | time/                   |             |
# |    fps                  | 1260        |
# |    iterations           | 6           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.016781913 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.9       |
# |    explained_variance   | 0.0077      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00739    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0329     |
# |    value_loss           | 0.0684      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.98        |
# |    ep_rew_mean          | 0.06        |
# | time/                   |             |
# |    fps                  | 1246        |
# |    iterations           | 7           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.018388975 |
# |    clip_fraction        | 0.252       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.8       |
# |    explained_variance   | 0.0266      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.018      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0379     |
# |    value_loss           | 0.0851      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.98       |
# |    ep_rew_mean          | 0.13       |
# | time/                   |            |
# |    fps                  | 1229       |
# |    iterations           | 8          |
# |    time_elapsed         | 13         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.02248206 |
# |    clip_fraction        | 0.309      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -10.7      |
# |    explained_variance   | 0.00423    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0232     |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.036     |
# |    value_loss           | 0.0901     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.1         |
# |    ep_rew_mean          | 0.18        |
# | time/                   |             |
# |    fps                  | 1215        |
# |    iterations           | 9           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.018542107 |
# |    clip_fraction        | 0.251       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.6       |
# |    explained_variance   | 0.0358      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0327      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0348     |
# |    value_loss           | 0.109       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.2         |
# |    ep_rew_mean          | 0.12        |
# | time/                   |             |
# |    fps                  | 1202        |
# |    iterations           | 10          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.022658153 |
# |    clip_fraction        | 0.279       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.5       |
# |    explained_variance   | 0.0432      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0014      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0381     |
# |    value_loss           | 0.12        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.16        |
# |    ep_rew_mean          | 0.18        |
# | time/                   |             |
# |    fps                  | 1189        |
# |    iterations           | 11          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.019849617 |
# |    clip_fraction        | 0.266       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.3       |
# |    explained_variance   | 0.0557      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00944    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0376     |
# |    value_loss           | 0.12        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.51        |
# |    ep_rew_mean          | 0.28        |
# | time/                   |             |
# |    fps                  | 1179        |
# |    iterations           | 12          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.018204322 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.2       |
# |    explained_variance   | 0.0341      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0335      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0356     |
# |    value_loss           | 0.119       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.39        |
# |    ep_rew_mean          | 0.25        |
# | time/                   |             |
# |    fps                  | 1169        |
# |    iterations           | 13          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.018712297 |
# |    clip_fraction        | 0.246       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10         |
# |    explained_variance   | 0.0404      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0189      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0345     |
# |    value_loss           | 0.128       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.52       |
# |    ep_rew_mean          | 0.26       |
# | time/                   |            |
# |    fps                  | 1140       |
# |    iterations           | 14         |
# |    time_elapsed         | 25         |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.01626166 |
# |    clip_fraction        | 0.206      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -9.94      |
# |    explained_variance   | 0.0626     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0204     |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.0327    |
# |    value_loss           | 0.145      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.53        |
# |    ep_rew_mean          | 0.24        |
# | time/                   |             |
# |    fps                  | 1117        |
# |    iterations           | 15          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.017729964 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.77       |
# |    explained_variance   | 0.0878      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0984      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0322     |
# |    value_loss           | 0.171       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.69        |
# |    ep_rew_mean          | 0.19        |
# | time/                   |             |
# |    fps                  | 1096        |
# |    iterations           | 16          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.017052874 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.62       |
# |    explained_variance   | 0.0745      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.04        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0321     |
# |    value_loss           | 0.156       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.68        |
# |    ep_rew_mean          | 0.3         |
# | time/                   |             |
# |    fps                  | 1079        |
# |    iterations           | 17          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.014226464 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.51       |
# |    explained_variance   | 0.0816      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0316      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0282     |
# |    value_loss           | 0.146       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.63        |
# |    ep_rew_mean          | 0.32        |
# | time/                   |             |
# |    fps                  | 1062        |
# |    iterations           | 18          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.016498074 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.39       |
# |    explained_variance   | 0.0599      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0523      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0293     |
# |    value_loss           | 0.165       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.9         |
# |    ep_rew_mean          | 0.36        |
# | time/                   |             |
# |    fps                  | 1051        |
# |    iterations           | 19          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.014344066 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.24       |
# |    explained_variance   | 0.0807      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0852      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0312     |
# |    value_loss           | 0.199       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.95        |
# |    ep_rew_mean          | 0.42        |
# | time/                   |             |
# |    fps                  | 1040        |
# |    iterations           | 20          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.011547549 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.12       |
# |    explained_variance   | 0.0685      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00773    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0266     |
# |    value_loss           | 0.179       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.87        |
# |    ep_rew_mean          | 0.39        |
# | time/                   |             |
# |    fps                  | 1029        |
# |    iterations           | 21          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.014105879 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.02       |
# |    explained_variance   | 0.0672      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.025       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0272     |
# |    value_loss           | 0.17        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.08       |
# |    ep_rew_mean          | 0.34       |
# | time/                   |            |
# |    fps                  | 1018       |
# |    iterations           | 22         |
# |    time_elapsed         | 44         |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.01477235 |
# |    clip_fraction        | 0.182      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -8.93      |
# |    explained_variance   | 0.0646     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0412     |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.0301    |
# |    value_loss           | 0.208      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.01        |
# |    ep_rew_mean          | 0.41        |
# | time/                   |             |
# |    fps                  | 1008        |
# |    iterations           | 23          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.011556767 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.77       |
# |    explained_variance   | 0.0674      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0705      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.027      |
# |    value_loss           | 0.193       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.2         |
# |    ep_rew_mean          | 0.4         |
# | time/                   |             |
# |    fps                  | 999         |
# |    iterations           | 24          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.010204929 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.71       |
# |    explained_variance   | 0.0827      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0721      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0249     |
# |    value_loss           | 0.238       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.14        |
# |    ep_rew_mean          | 0.34        |
# | time/                   |             |
# |    fps                  | 992         |
# |    iterations           | 25          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.012726616 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.68       |
# |    explained_variance   | 0.0896      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0655      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.027      |
# |    value_loss           | 0.216       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.02         |
# |    ep_rew_mean          | 0.38         |
# | time/                   |              |
# |    fps                  | 985          |
# |    iterations           | 26           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0120637305 |
# |    clip_fraction        | 0.155        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -8.56        |
# |    explained_variance   | 0.101        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0576       |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.0295      |
# |    value_loss           | 0.197        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.16        |
# |    ep_rew_mean          | 0.48        |
# | time/                   |             |
# |    fps                  | 978         |
# |    iterations           | 27          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.012271645 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.46       |
# |    explained_variance   | 0.081       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0654      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0268     |
# |    value_loss           | 0.196       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.34        |
# |    ep_rew_mean          | 0.4         |
# | time/                   |             |
# |    fps                  | 972         |
# |    iterations           | 28          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.012670457 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.36       |
# |    explained_variance   | 0.0935      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0634      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0277     |
# |    value_loss           | 0.228       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.16         |
# |    ep_rew_mean          | 0.43         |
# | time/                   |              |
# |    fps                  | 966          |
# |    iterations           | 29           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0131033845 |
# |    clip_fraction        | 0.14         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -8.24        |
# |    explained_variance   | 0.0937       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0281       |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.0262      |
# |    value_loss           | 0.212        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.27        |
# |    ep_rew_mean          | 0.44        |
# | time/                   |             |
# |    fps                  | 961         |
# |    iterations           | 30          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.011538423 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.12       |
# |    explained_variance   | 0.0735      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0991      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0284     |
# |    value_loss           | 0.244       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.52        |
# |    ep_rew_mean          | 0.56        |
# | time/                   |             |
# |    fps                  | 955         |
# |    iterations           | 31          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.011396726 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.04       |
# |    explained_variance   | 0.0828      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.196       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0273     |
# |    value_loss           | 0.255       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.27        |
# |    ep_rew_mean          | 0.41        |
# | time/                   |             |
# |    fps                  | 951         |
# |    iterations           | 32          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.015213799 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.96       |
# |    explained_variance   | 0.11        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0364      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0321     |
# |    value_loss           | 0.269       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.56        |
# |    ep_rew_mean          | 0.45        |
# | time/                   |             |
# |    fps                  | 946         |
# |    iterations           | 33          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.013311867 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.9        |
# |    explained_variance   | 0.101       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0741      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0297     |
# |    value_loss           | 0.258       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.6         |
# |    ep_rew_mean          | 0.6         |
# | time/                   |             |
# |    fps                  | 942         |
# |    iterations           | 34          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.011420107 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.77       |
# |    explained_variance   | 0.112       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0215      |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0266     |
# |    value_loss           | 0.25        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.36        |
# |    ep_rew_mean          | 0.45        |
# | time/                   |             |
# |    fps                  | 938         |
# |    iterations           | 35          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.013531997 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.74       |
# |    explained_variance   | 0.121       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.107       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0313     |
# |    value_loss           | 0.251       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.84        |
# |    ep_rew_mean          | 0.49        |
# | time/                   |             |
# |    fps                  | 934         |
# |    iterations           | 36          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.013148781 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.6        |
# |    explained_variance   | 0.131       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0588      |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0309     |
# |    value_loss           | 0.257       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.82        |
# |    ep_rew_mean          | 0.46        |
# | time/                   |             |
# |    fps                  | 930         |
# |    iterations           | 37          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.015040249 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.47       |
# |    explained_variance   | 0.104       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0874      |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0335     |
# |    value_loss           | 0.294       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.97        |
# |    ep_rew_mean          | 0.65        |
# | time/                   |             |
# |    fps                  | 926         |
# |    iterations           | 38          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.012614481 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.25       |
# |    explained_variance   | 0.129       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0518      |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0257     |
# |    value_loss           | 0.276       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.81        |
# |    ep_rew_mean          | 0.53        |
# | time/                   |             |
# |    fps                  | 922         |
# |    iterations           | 39          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.012801519 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.1        |
# |    explained_variance   | 0.134       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.15        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0321     |
# |    value_loss           | 0.341       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.96        |
# |    ep_rew_mean          | 0.71        |
# | time/                   |             |
# |    fps                  | 919         |
# |    iterations           | 40          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.013375431 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.94       |
# |    explained_variance   | 0.112       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0624      |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0281     |
# |    value_loss           | 0.311       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.9         |
# |    ep_rew_mean          | 0.58        |
# | time/                   |             |
# |    fps                  | 915         |
# |    iterations           | 41          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.012946815 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.75       |
# |    explained_variance   | 0.118       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0748      |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0303     |
# |    value_loss           | 0.301       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.03        |
# |    ep_rew_mean          | 0.7         |
# | time/                   |             |
# |    fps                  | 911         |
# |    iterations           | 42          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.012118261 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.68       |
# |    explained_variance   | 0.104       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.12        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0262     |
# |    value_loss           | 0.362       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.15        |
# |    ep_rew_mean          | 0.86        |
# | time/                   |             |
# |    fps                  | 908         |
# |    iterations           | 43          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.014762379 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.5        |
# |    explained_variance   | 0.118       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0885      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.034      |
# |    value_loss           | 0.362       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.21        |
# |    ep_rew_mean          | 0.91        |
# | time/                   |             |
# |    fps                  | 904         |
# |    iterations           | 44          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.014518254 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.31       |
# |    explained_variance   | 0.15        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.18        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0355     |
# |    value_loss           | 0.36        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.32        |
# |    ep_rew_mean          | 0.84        |
# | time/                   |             |
# |    fps                  | 901         |
# |    iterations           | 45          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.013514566 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.11       |
# |    explained_variance   | 0.174       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.159       |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0319     |
# |    value_loss           | 0.366       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.67       |
# |    ep_rew_mean          | 0.92       |
# | time/                   |            |
# |    fps                  | 897        |
# |    iterations           | 46         |
# |    time_elapsed         | 105        |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.01469841 |
# |    clip_fraction        | 0.201      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.97      |
# |    explained_variance   | 0.135      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.143      |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.0336    |
# |    value_loss           | 0.416      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.59        |
# |    ep_rew_mean          | 0.92        |
# | time/                   |             |
# |    fps                  | 893         |
# |    iterations           | 47          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.014852459 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.76       |
# |    explained_variance   | 0.174       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.176       |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0314     |
# |    value_loss           | 0.41        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.72        |
# |    ep_rew_mean          | 1.02        |
# | time/                   |             |
# |    fps                  | 888         |
# |    iterations           | 48          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.016605504 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.59       |
# |    explained_variance   | 0.186       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.16        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0349     |
# |    value_loss           | 0.442       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.62        |
# |    ep_rew_mean          | 1.2         |
# | time/                   |             |
# |    fps                  | 884         |
# |    iterations           | 49          |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.014048024 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.48       |
# |    explained_variance   | 0.208       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.167       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0298     |
# |    value_loss           | 0.481       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.99        |
# |    ep_rew_mean          | 1.36        |
# | time/                   |             |
# |    fps                  | 879         |
# |    iterations           | 50          |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.014890051 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.2        |
# |    explained_variance   | 0.196       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.286       |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0328     |
# |    value_loss           | 0.543       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.9        |
# |    ep_rew_mean          | 1.17       |
# | time/                   |            |
# |    fps                  | 875        |
# |    iterations           | 51         |
# |    time_elapsed         | 119        |
# |    total_timesteps      | 104448     |
# | train/                  |            |
# |    approx_kl            | 0.01631165 |
# |    clip_fraction        | 0.198      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.02      |
# |    explained_variance   | 0.239      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.38       |
# |    n_updates            | 500        |
# |    policy_gradient_loss | -0.0364    |
# |    value_loss           | 0.534      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.08       |
# |    ep_rew_mean          | 1.04       |
# | time/                   |            |
# |    fps                  | 870        |
# |    iterations           | 52         |
# |    time_elapsed         | 122        |
# |    total_timesteps      | 106496     |
# | train/                  |            |
# |    approx_kl            | 0.01903436 |
# |    clip_fraction        | 0.188      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.86      |
# |    explained_variance   | 0.243      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.207      |
# |    n_updates            | 510        |
# |    policy_gradient_loss | -0.038     |
# |    value_loss           | 0.488      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.24         |
# |    ep_rew_mean          | 1.39         |
# | time/                   |              |
# |    fps                  | 866          |
# |    iterations           | 53           |
# |    time_elapsed         | 125          |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0153264385 |
# |    clip_fraction        | 0.158        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.7         |
# |    explained_variance   | 0.271        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.169        |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.0367      |
# |    value_loss           | 0.568        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.98        |
# |    ep_rew_mean          | 1.39        |
# | time/                   |             |
# |    fps                  | 861         |
# |    iterations           | 54          |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.015433975 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.45       |
# |    explained_variance   | 0.275       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.361       |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.0347     |
# |    value_loss           | 0.575       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.82        |
# |    ep_rew_mean          | 1.46        |
# | time/                   |             |
# |    fps                  | 856         |
# |    iterations           | 55          |
# |    time_elapsed         | 131         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.019777212 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.22       |
# |    explained_variance   | 0.333       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.229       |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.0416     |
# |    value_loss           | 0.512       |
# -----------------------------------------
# ...
# |    n_updates            | 3700        |
# |    policy_gradient_loss | -0.0383     |
# |    value_loss           | 1.94        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.41        |
# |    ep_rew_mean          | 7.81        |
# | time/                   |             |
# |    fps                  | 429         |
# |    iterations           | 372         |
# |    time_elapsed         | 1773        |
# |    total_timesteps      | 761856      |
# | train/                  |             |
# |    approx_kl            | 0.047840845 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.78       |
# |    explained_variance   | 0.901       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0458      |
# |    n_updates            | 3710        |
# |    policy_gradient_loss | -0.0141     |
# |    value_loss           | 0.411       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.77       |
# |    ep_rew_mean          | 8.48       |
# | time/                   |            |
# |    fps                  | 429        |
# |    iterations           | 373        |
# |    time_elapsed         | 1778       |
# |    total_timesteps      | 763904     |
# | train/                  |            |
# |    approx_kl            | 0.20313908 |
# |    clip_fraction        | 0.207      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.537     |
# |    explained_variance   | 0.926      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.18       |
# |    n_updates            | 3720       |
# |    policy_gradient_loss | -0.0355    |
# |    value_loss           | 0.517      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.77       |
# |    ep_rew_mean          | 8.72       |
# | time/                   |            |
# |    fps                  | 429        |
# |    iterations           | 374        |
# |    time_elapsed         | 1783       |
# |    total_timesteps      | 765952     |
# | train/                  |            |
# |    approx_kl            | 0.04187315 |
# |    clip_fraction        | 0.0806     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.674     |
# |    explained_variance   | 0.961      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0335     |
# |    n_updates            | 3730       |
# |    policy_gradient_loss | -0.0138    |
# |    value_loss           | 0.233      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.66        |
# |    ep_rew_mean          | 8.63        |
# | time/                   |             |
# |    fps                  | 429         |
# |    iterations           | 375         |
# |    time_elapsed         | 1788        |
# |    total_timesteps      | 768000      |
# | train/                  |             |
# |    approx_kl            | 0.018384103 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.56       |
# |    explained_variance   | 0.977       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.144       |
# |    n_updates            | 3740        |
# |    policy_gradient_loss | -0.0175     |
# |    value_loss           | 0.173       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.1        |
# |    ep_rew_mean          | 9.04        |
# | time/                   |             |
# |    fps                  | 429         |
# |    iterations           | 376         |
# |    time_elapsed         | 1793        |
# |    total_timesteps      | 770048      |
# | train/                  |             |
# |    approx_kl            | 0.019863881 |
# |    clip_fraction        | 0.0588      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.615      |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0265      |
# |    n_updates            | 3750        |
# |    policy_gradient_loss | -0.0138     |
# |    value_loss           | 0.0479      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 8.98        |
# | time/                   |             |
# |    fps                  | 429         |
# |    iterations           | 377         |
# |    time_elapsed         | 1798        |
# |    total_timesteps      | 772096      |
# | train/                  |             |
# |    approx_kl            | 0.008535472 |
# |    clip_fraction        | 0.0474      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.628      |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0181     |
# |    n_updates            | 3760        |
# |    policy_gradient_loss | -0.00789    |
# |    value_loss           | 0.0216      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.98       |
# |    ep_rew_mean          | 6.94       |
# | time/                   |            |
# |    fps                  | 429        |
# |    iterations           | 378        |
# |    time_elapsed         | 1803       |
# |    total_timesteps      | 774144     |
# | train/                  |            |
# |    approx_kl            | 0.27519843 |
# |    clip_fraction        | 0.173      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.705     |
# |    explained_variance   | 0.996      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0267    |
# |    n_updates            | 3770       |
# |    policy_gradient_loss | -0.0183    |
# |    value_loss           | 0.024      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 7.53      |
# |    ep_rew_mean          | 6.48      |
# | time/                   |           |
# |    fps                  | 429       |
# |    iterations           | 379       |
# |    time_elapsed         | 1808      |
# |    total_timesteps      | 776192    |
# | train/                  |           |
# |    approx_kl            | 0.0997462 |
# |    clip_fraction        | 0.182     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.211    |
# |    explained_variance   | 0.981     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0221   |
# |    n_updates            | 3780      |
# |    policy_gradient_loss | -0.0369   |
# |    value_loss           | 0.143     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8.15       |
# |    ep_rew_mean          | 7.06       |
# | time/                   |            |
# |    fps                  | 429        |
# |    iterations           | 380        |
# |    time_elapsed         | 1813       |
# |    total_timesteps      | 778240     |
# | train/                  |            |
# |    approx_kl            | 0.06661868 |
# |    clip_fraction        | 0.246      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.278     |
# |    explained_variance   | 0.745      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.476      |
# |    n_updates            | 3790       |
# |    policy_gradient_loss | -0.0419    |
# |    value_loss           | 1.22       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.08       |
# |    ep_rew_mean          | 8.04       |
# | time/                   |            |
# |    fps                  | 428        |
# |    iterations           | 381        |
# |    time_elapsed         | 1818       |
# |    total_timesteps      | 780288     |
# | train/                  |            |
# |    approx_kl            | 0.06616044 |
# |    clip_fraction        | 0.168      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.285     |
# |    explained_variance   | 0.857      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.367      |
# |    n_updates            | 3800       |
# |    policy_gradient_loss | -0.033     |
# |    value_loss           | 0.786      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.58        |
# |    ep_rew_mean          | 8.55        |
# | time/                   |             |
# |    fps                  | 428         |
# |    iterations           | 382         |
# |    time_elapsed         | 1824        |
# |    total_timesteps      | 782336      |
# | train/                  |             |
# |    approx_kl            | 0.018160349 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.438      |
# |    explained_variance   | 0.911       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.17        |
# |    n_updates            | 3810        |
# |    policy_gradient_loss | -0.0289     |
# |    value_loss           | 0.567       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 8.99       |
# | time/                   |            |
# |    fps                  | 428        |
# |    iterations           | 383        |
# |    time_elapsed         | 1829       |
# |    total_timesteps      | 784384     |
# | train/                  |            |
# |    approx_kl            | 0.11255097 |
# |    clip_fraction        | 0.0959     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.453     |
# |    explained_variance   | 0.95       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.218      |
# |    n_updates            | 3820       |
# |    policy_gradient_loss | -0.0233    |
# |    value_loss           | 0.352      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.66        |
# |    ep_rew_mean          | 8.63        |
# | time/                   |             |
# |    fps                  | 428         |
# |    iterations           | 384         |
# |    time_elapsed         | 1835        |
# |    total_timesteps      | 786432      |
# | train/                  |             |
# |    approx_kl            | 0.010703457 |
# |    clip_fraction        | 0.0957      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.652      |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0201     |
# |    n_updates            | 3830        |
# |    policy_gradient_loss | -0.0119     |
# |    value_loss           | 0.0286      |
# -----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 6
#       3 policy_kwargs = dict(activation_fn=th.nn.Tanh,
#       4                      net_arch=dict(pi=[128, 128, 128], vf=[128, 128, 128]))
#       5 model = PPO("MlpPolicy", env = gym.wrappers.time_limit.TimeLimit(PrimeEnv(),100), verbose = 1)
# ----> 6 model.learn(1e7)
#
# File ~/.local/lib/python3.10/site-packages/stable_baselines3/ppo/ppo.py:308, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     299 def learn(
#     300     self: SelfPPO,
#     301     total_timesteps: int,
#    (...)
#     306     progress_bar: bool = False,
#     307 ) -> SelfPPO:
# --> 308     return super().learn(
#     309         total_timesteps=total_timesteps,
#     310         callback=callback,
#     311         log_interval=log_interval,
#     312         tb_log_name=tb_log_name,
#     313         reset_num_timesteps=reset_num_timesteps,
#     314         progress_bar=progress_bar,
#     315     )
#
# File ~/.local/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:259, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     256 assert self.env is not None
#     258 while self.num_timesteps < total_timesteps:
# --> 259     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     261     if continue_training is False:
#     262         break
#
# File ~/.local/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:178, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     175 if isinstance(self.action_space, spaces.Box):
#     176     clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
# --> 178 new_obs, rewards, dones, infos = env.step(clipped_actions)
#     180 self.num_timesteps += env.num_envs
#     182 # Give access to local variables
#
# File ~/.local/lib/python3.10/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:197, in VecEnv.step(self, actions)
#     190 """
#     191 Step the environments with the given action
#     192
#     193 :param actions: the action
#     194 :return: observation, reward, done, information
#     195 """
#     196 self.step_async(actions)
# --> 197 return self.step_wait()
#
# File ~/.local/lib/python3.10/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:58, in DummyVecEnv.step_wait(self)
#      55 def step_wait(self) -> VecEnvStepReturn:
#      56     # Avoid circular imports
#      57     for env_idx in range(self.num_envs):
# ---> 58         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      59             self.actions[env_idx]
#      60         )
#      61         # convert to SB3 VecEnv api
#      62         self.buf_dones[env_idx] = terminated or truncated
#
# File ~/.local/lib/python3.10/site-packages/stable_baselines3/common/monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, terminated, truncated, info = self.env.step(action)
#      95 self.rewards.append(float(reward))
#      96 if terminated or truncated:
#
# File ~/.local/lib/python3.10/site-packages/gymnasium/wrappers/time_limit.py:57, in TimeLimit.step(self, action)
#      46 def step(self, action):
#      47     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#      48
#      49     Args:
#    (...)
#      55
#      56     """
# ---> 57     observation, reward, terminated, truncated, info = self.env.step(action)
#      58     self._elapsed_steps += 1
#      60     if self._elapsed_steps >= self._max_episode_steps:
#
# Cell In[25], line 16, in PrimeEnv.step(self, action)
#      14 done = False
#      15 if next_state_decimal > self.binatodeci(self.state_):
# ---> 16     if self.is_prime(next_state_decimal):
#      17         reward = 1
#      18     else:
#
# Cell In[25], line 36, in PrimeEnv.is_prime(self, state)
#      31 if tmp_state > 1:
#      32 # Iterate from 2 to n // 2
#      33     for i in range(2, (tmp_state//2)+1):
#      34         # If num is divisible by any number between
#      35         # 2 and n / 2, it is not prime
# ---> 36         if (tmp_state % i) == 0:
#      37             return 0
#      38     else:
#
# KeyboardInterrupt:

# %%
#Generate primes

env = PrimeEnv()
for ep in range(100):
    s, _ = env.reset()
    print("Starting number: {}".format(env.binatodeci(s)))
    done = False
    while not done:
        a = model.predict(s, deterministic=True)[0]
        print("Next number predicted: {}".format(env.binatodeci(s)))
        s, r, done, _, _ = env.step(a)
        print("Is prime: {}".format(bool(r)))
# Out:
# Starting number: 40760
# Next number predicted: 40760
# Is prime: True
# Next number predicted: 49171.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 58413
# Next number predicted: 58413
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 37398
# Next number predicted: 37398
# Is prime: True
# Next number predicted: 49171.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 27940
# Next number predicted: 27940
# Is prime: True
# Next number predicted: 33533.0
# Is prime: True
# Next number predicted: 49169.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 22137
# Next number predicted: 22137
# Is prime: True
# Next number predicted: 33533.0
# Is prime: True
# Next number predicted: 49169.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 38425
# Next number predicted: 38425
# Is prime: True
# Next number predicted: 49171.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 28698
# Next number predicted: 28698
# Is prime: True
# Next number predicted: 32917.0
# Is prime: True
# Next number predicted: 49171.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 26633
# Next number predicted: 26633
# Is prime: True
# Next number predicted: 33533.0
# Is prime: True
# Next number predicted: 49169.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 28758
# Next number predicted: 28758
# Is prime: True
# Next number predicted: 32917.0
# Is prime: True
# Next number predicted: 49171.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 31666
# Next number predicted: 31666
# Is prime: True
# Next number predicted: 33469.0
# Is prime: True
# Next number predicted: 49171.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 23672
# Next number predicted: 23672
# Is prime: True
# Next number predicted: 33533.0
# Is prime: True
# Next number predicted: 49169.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 4472
# Next number predicted: 4472
# Is prime: True
# Next number predicted: 33469.0
# Is prime: True
# Next number predicted: 49171.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 33113
# Next number predicted: 33113
# Is prime: True
# Next number predicted: 49171.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 52995
# Next number predicted: 52995
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 42843
# Next number predicted: 42843
# Is prime: True
# Next number predicted: 49169.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 63351
# Next number predicted: 63351
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 38686
# Next number predicted: 38686
# Is prime: True
# Next number predicted: 49171.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 28010
# Next number predicted: 28010
# Is prime: True
# Next number predicted: 33533.0
# Is prime: True
# Next number predicted: 49169.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 1596
# Next number predicted: 1596
# Is prime: True
# Next number predicted: 33469.0
# Is prime: True
# Next number predicted: 49171.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 47795
# Next number predicted: 47795
# Is prime: True
# Next number predicted: 49169.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 31666
# Next number predicted: 31666
# Is prime: True
# Next number predicted: 33469.0
# Is prime: True
# Next number predicted: 49171.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 10976
# Next number predicted: 10976
# Is prime: True
# Next number predicted: 33533.0
# Is prime: True
# Next number predicted: 49169.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 14874
# Next number predicted: 14874
# Is prime: True
# Next number predicted: 33533.0
# Is prime: True
# Next number predicted: 49169.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 64233
# Next number predicted: 64233
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 33712
# Next number predicted: 33712
# Is prime: True
# Next number predicted: 49171.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 52708
# Next number predicted: 52708
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 52503
# Next number predicted: 52503
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 13370
# Next number predicted: 13370
# Is prime: True
# Next number predicted: 33469.0
# Is prime: True
# Next number predicted: 49171.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 24860
# Next number predicted: 24860
# Is prime: True
# Next number predicted: 32917.0
# Is prime: True
# Next number predicted: 49171.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 22005
# Next number predicted: 22005
# Is prime: True
# Next number predicted: 33469.0
# Is prime: True
# Next number predicted: 49171.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 43025
# Next number predicted: 43025
# Is prime: True
# Next number predicted: 49169.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 46853
# Next number predicted: 46853
# Is prime: True
# Next number predicted: 49169.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 38127
# Next number predicted: 38127
# Is prime: True
# Next number predicted: 49171.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 50510
# Next number predicted: 50510
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 60382
# Next number predicted: 60382
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 53813
# Next number predicted: 53813
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 25965
# Next number predicted: 25965
# Is prime: True
# Next number predicted: 33533.0
# Is prime: True
# Next number predicted: 49169.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 26736
# Next number predicted: 26736
# Is prime: True
# Next number predicted: 33533.0
# Is prime: True
# Next number predicted: 49169.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 46403
# Next number predicted: 46403
# Is prime: True
# Next number predicted: 49169.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 3895
# Next number predicted: 3895
# Is prime: True
# Next number predicted: 33533.0
# Is prime: True
# Next number predicted: 49169.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 40926
# Next number predicted: 40926
# Is prime: True
# Next number predicted: 49171.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 54680
# Next number predicted: 54680
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 31691
# Next number predicted: 31691
# Is prime: True
# Next number predicted: 33533.0
# Is prime: True
# Next number predicted: 49169.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 49256
# Next number predicted: 49256
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 25499
# Next number predicted: 25499
# Is prime: True
# Next number predicted: 32957.0
# Is prime: True
# Next number predicted: 49171.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 47970
# Next number predicted: 47970
# Is prime: True
# Next number predicted: 49169.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 59657
# Next number predicted: 59657
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 51617
# Next number predicted: 51617
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 25618
# Next number predicted: 25618
# Is prime: True
# Next number predicted: 32917.0
# Is prime: True
# Next number predicted: 49171.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 43588
# Next number predicted: 43588
# Is prime: True
# Next number predicted: 49169.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 33436
# Next number predicted: 33436
# Is prime: True
# Next number predicted: 49171.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 18847
# Next number predicted: 18847
# Is prime: True
# Next number predicted: 32957.0
# Is prime: True
# Next number predicted: 49171.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 61949
# Next number predicted: 61949
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 3100
# Next number predicted: 3100
# Is prime: True
# Next number predicted: 33533.0
# Is prime: True
# Next number predicted: 49169.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 48278
# Next number predicted: 48278
# Is prime: True
# Next number predicted: 49169.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 17936
# Next number predicted: 17936
# Is prime: True
# Next number predicted: 33533.0
# Is prime: True
# Next number predicted: 49169.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 32638
# Next number predicted: 32638
# Is prime: True
# Next number predicted: 33533.0
# Is prime: True
# Next number predicted: 49169.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 35096
# Next number predicted: 35096
# Is prime: True
# Next number predicted: 49171.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 26196
# Next number predicted: 26196
# Is prime: True
# Next number predicted: 33533.0
# Is prime: True
# Next number predicted: 49169.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 49467
# Next number predicted: 49467
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 1893
# Next number predicted: 1893
# Is prime: True
# Next number predicted: 33469.0
# Is prime: True
# Next number predicted: 49171.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 11240
# Next number predicted: 11240
# Is prime: True
# Next number predicted: 33533.0
# Is prime: True
# Next number predicted: 49169.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 55749
# Next number predicted: 55749
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 20778
# Next number predicted: 20778
# Is prime: True
# Next number predicted: 32957.0
# Is prime: True
# Next number predicted: 49171.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 22417
# Next number predicted: 22417
# Is prime: True
# Next number predicted: 33469.0
# Is prime: True
# Next number predicted: 49171.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 45840
# Next number predicted: 45840
# Is prime: True
# Next number predicted: 49169.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 55193
# Next number predicted: 55193
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 43690
# Next number predicted: 43690
# Is prime: True
# Next number predicted: 49169.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 63008
# Next number predicted: 63008
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 8488
# Next number predicted: 8488
# Is prime: True
# Next number predicted: 33469.0
# Is prime: True
# Next number predicted: 49171.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 27925
# Next number predicted: 27925
# Is prime: True
# Next number predicted: 33533.0
# Is prime: True
# Next number predicted: 49169.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 40310
# Next number predicted: 40310
# Is prime: True
# Next number predicted: 49171.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 54353
# Next number predicted: 54353
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 14041
# Next number predicted: 14041
# Is prime: True
# Next number predicted: 33469.0
# Is prime: True
# Next number predicted: 49171.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 63236
# Next number predicted: 63236
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 1038
# Next number predicted: 1038
# Is prime: True
# Next number predicted: 32957.0
# Is prime: True
# Next number predicted: 49171.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 17855
# Next number predicted: 17855
# Is prime: True
# Next number predicted: 32917.0
# Is prime: True
# Next number predicted: 49171.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 9849
# Next number predicted: 9849
# Is prime: True
# Next number predicted: 33533.0
# Is prime: True
# Next number predicted: 49169.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 50678
# Next number predicted: 50678
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 40941
# Next number predicted: 40941
# Is prime: True
# Next number predicted: 49171.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 15340
# Next number predicted: 15340
# Is prime: True
# Next number predicted: 33469.0
# Is prime: True
# Next number predicted: 49171.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 8034
# Next number predicted: 8034
# Is prime: True
# Next number predicted: 33533.0
# Is prime: True
# Next number predicted: 49169.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 49604
# Next number predicted: 49604
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 47219
# Next number predicted: 47219
# Is prime: True
# Next number predicted: 49169.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 54343
# Next number predicted: 54343
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 20949
# Next number predicted: 20949
# Is prime: True
# Next number predicted: 32917.0
# Is prime: True
# Next number predicted: 49171.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 46276
# Next number predicted: 46276
# Is prime: True
# Next number predicted: 49169.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 37488
# Next number predicted: 37488
# Is prime: True
# Next number predicted: 49171.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 24863
# Next number predicted: 24863
# Is prime: True
# Next number predicted: 32917.0
# Is prime: True
# Next number predicted: 49171.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 26315
# Next number predicted: 26315
# Is prime: True
# Next number predicted: 33533.0
# Is prime: True
# Next number predicted: 49169.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 49471
# Next number predicted: 49471
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 31893
# Next number predicted: 31893
# Is prime: True
# Next number predicted: 33533.0
# Is prime: True
# Next number predicted: 49169.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 17337
# Next number predicted: 17337
# Is prime: True
# Next number predicted: 32957.0
# Is prime: True
# Next number predicted: 49171.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 64547
# Next number predicted: 64547
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 11962
# Next number predicted: 11962
# Is prime: True
# Next number predicted: 33533.0
# Is prime: True
# Next number predicted: 49169.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 32752
# Next number predicted: 32752
# Is prime: True
# Next number predicted: 33533.0
# Is prime: True
# Next number predicted: 49169.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 61179
# Next number predicted: 61179
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 59142
# Next number predicted: 59142
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 10745
# Next number predicted: 10745
# Is prime: True
# Next number predicted: 33469.0
# Is prime: True
# Next number predicted: 49171.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False
# Starting number: 36445
# Next number predicted: 36445
# Is prime: True
# Next number predicted: 49171.0
# Is prime: True
# Next number predicted: 57347.0
# Is prime: True
# Next number predicted: 61441.0
# Is prime: True
# Next number predicted: 64513.0
# Is prime: True
# Next number predicted: 64577.0
# Is prime: True
# Next number predicted: 65089.0
# Is prime: True
# Next number predicted: 65129.0
# Is prime: True
# Next number predicted: 65257.0
# Is prime: True
# Next number predicted: 65269.0
# Is prime: False

# %%
# !pip install stable-baselines3

# %%
import gymnasium as gym
import numpy as np
from gymnasium import spaces
from stable_baselines3 import PPO
import torch as th

# %%
def binatodeci(binary):
        return sum(val*(2**idx) for idx, val in enumerate(reversed(binary)))

# %%
primes = {}
for i in range(1, int(binatodeci(np.ones(16)))+1):
    # Iterate from 2 to n // 2
    is_prime=1
    for j in range(2, (i//2)+1):
        # If num is divisible by any number between
        # 2 and n / 2, it is not prime
        if (i % j) == 0:
            is_prime = 0
            break
    primes[i] = is_prime

primes[1] = 1

# %%
class PrimeEnv(gym.Env):
    def __init__(self, max_bits=16):
        self.observation_space = spaces.MultiBinary(max_bits)
        self.action_space = spaces.MultiBinary(max_bits)
    
    def reset(self, **kwargs):
        start_state = np.random.choice(np.array(list(primes.keys())))
        self.state_deci = start_state
        start_state = [int(i) for i in list('{0:0b}'.format(start_state))]
        start_state = [0] * (16 - len(start_state)) + start_state
        start_state = np.array(start_state)
        self.state_bin = start_state
        return start_state, {}
    
    def step(self, action):
        next_state_bin = action
        next_state_decimal = binatodeci(next_state_bin)
        done = False
        if next_state_decimal < self.state_deci:
            done = True
        
        reward = primes[next_state_decimal]
        self.state_deci = next_state_decimal,
        self.state_bin = next_state_bin
        return next_state_bin, reward, done, False, {}

# %%
model = PPO("MlpPolicy", env = gym.wrappers.time_limit.TimeLimit(PrimeEnv(),500), verbose = 1)
model.learn(1e6)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.76     |
# |    ep_rew_mean     | 0.18     |
# | time/              |          |
# |    fps             | 334      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.75        |
# |    ep_rew_mean          | 0.08        |
# | time/                   |             |
# |    fps                  | 307         |
# |    iterations           | 2           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.014983747 |
# |    clip_fraction        | 0.253       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.1       |
# |    explained_variance   | -1.08       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0612      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0372     |
# |    value_loss           | 0.144       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.81        |
# |    ep_rew_mean          | 0.28        |
# | time/                   |             |
# |    fps                  | 305         |
# |    iterations           | 3           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.019640379 |
# |    clip_fraction        | 0.382       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11         |
# |    explained_variance   | -0.0124     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0551      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0475     |
# |    value_loss           | 0.162       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.68        |
# |    ep_rew_mean          | 0.34        |
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 4           |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.015083629 |
# |    clip_fraction        | 0.283       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11         |
# |    explained_variance   | -0.0129     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0321      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0365     |
# |    value_loss           | 0.173       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.77       |
# |    ep_rew_mean          | 0.31       |
# | time/                   |            |
# |    fps                  | 300        |
# |    iterations           | 5          |
# |    time_elapsed         | 34         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.01628048 |
# |    clip_fraction        | 0.258      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -10.9      |
# |    explained_variance   | 0.00644    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0587     |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0364    |
# |    value_loss           | 0.203      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.92        |
# |    ep_rew_mean          | 0.32        |
# | time/                   |             |
# |    fps                  | 293         |
# |    iterations           | 6           |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.017555047 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.8       |
# |    explained_variance   | 0.0171      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0748      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0359     |
# |    value_loss           | 0.202       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.75        |
# |    ep_rew_mean          | 0.29        |
# | time/                   |             |
# |    fps                  | 290         |
# |    iterations           | 7           |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.013217946 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.7       |
# |    explained_variance   | 0.0136      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0778      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0323     |
# |    value_loss           | 0.234       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.88        |
# |    ep_rew_mean          | 0.37        |
# | time/                   |             |
# |    fps                  | 290         |
# |    iterations           | 8           |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.013218783 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.6       |
# |    explained_variance   | 0.0278      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0804      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0309     |
# |    value_loss           | 0.241       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.84        |
# |    ep_rew_mean          | 0.35        |
# | time/                   |             |
# |    fps                  | 290         |
# |    iterations           | 9           |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.013452306 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.5       |
# |    explained_variance   | 0.00843     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0744      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0264     |
# |    value_loss           | 0.225       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.94        |
# |    ep_rew_mean          | 0.48        |
# | time/                   |             |
# |    fps                  | 289         |
# |    iterations           | 10          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.013631443 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.5       |
# |    explained_variance   | 0.013       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.108       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0281     |
# |    value_loss           | 0.265       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.94        |
# |    ep_rew_mean          | 0.42        |
# | time/                   |             |
# |    fps                  | 292         |
# |    iterations           | 11          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.011908911 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.4       |
# |    explained_variance   | 0.012       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.128       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.028      |
# |    value_loss           | 0.258       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.09        |
# |    ep_rew_mean          | 0.36        |
# | time/                   |             |
# |    fps                  | 293         |
# |    iterations           | 12          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.010377563 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.3       |
# |    explained_variance   | -0.00925    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.081       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0252     |
# |    value_loss           | 0.256       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.14        |
# |    ep_rew_mean          | 0.27        |
# | time/                   |             |
# |    fps                  | 291         |
# |    iterations           | 13          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.013534848 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.2       |
# |    explained_variance   | 0.0137      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0929      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0286     |
# |    value_loss           | 0.247       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.05        |
# |    ep_rew_mean          | 0.27        |
# | time/                   |             |
# |    fps                  | 289         |
# |    iterations           | 14          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.012418874 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.1       |
# |    explained_variance   | 0.0317      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0826      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.026      |
# |    value_loss           | 0.267       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.29        |
# |    ep_rew_mean          | 0.36        |
# | time/                   |             |
# |    fps                  | 289         |
# |    iterations           | 15          |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.012532707 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10         |
# |    explained_variance   | 0.0229      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0406      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0286     |
# |    value_loss           | 0.26        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.3         |
# |    ep_rew_mean          | 0.42        |
# | time/                   |             |
# |    fps                  | 289         |
# |    iterations           | 16          |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.011343639 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.96       |
# |    explained_variance   | 0.00912     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0778      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0274     |
# |    value_loss           | 0.286       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.45        |
# |    ep_rew_mean          | 0.4         |
# | time/                   |             |
# |    fps                  | 288         |
# |    iterations           | 17          |
# |    time_elapsed         | 120         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.012512656 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.88       |
# |    explained_variance   | 0.0292      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.104       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0292     |
# |    value_loss           | 0.282       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.33        |
# |    ep_rew_mean          | 0.41        |
# | time/                   |             |
# |    fps                  | 289         |
# |    iterations           | 18          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.011854817 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.8        |
# |    explained_variance   | 0.0289      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.114       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0241     |
# |    value_loss           | 0.287       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.54        |
# |    ep_rew_mean          | 0.58        |
# | time/                   |             |
# |    fps                  | 289         |
# |    iterations           | 19          |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.011252826 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.72       |
# |    explained_variance   | 0.0235      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.11        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0256     |
# |    value_loss           | 0.265       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.45        |
# |    ep_rew_mean          | 0.4         |
# | time/                   |             |
# |    fps                  | 290         |
# |    iterations           | 20          |
# |    time_elapsed         | 140         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.011264728 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.62       |
# |    explained_variance   | 0.043       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0995      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0234     |
# |    value_loss           | 0.329       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.49        |
# |    ep_rew_mean          | 0.46        |
# | time/                   |             |
# |    fps                  | 294         |
# |    iterations           | 21          |
# |    time_elapsed         | 146         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.010625519 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.54       |
# |    explained_variance   | 0.014       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0884      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0231     |
# |    value_loss           | 0.299       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.73       |
# |    ep_rew_mean          | 0.44       |
# | time/                   |            |
# |    fps                  | 295        |
# |    iterations           | 22         |
# |    time_elapsed         | 152        |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.01312054 |
# |    clip_fraction        | 0.155      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -9.46      |
# |    explained_variance   | 0.0212     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.136      |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.0298    |
# |    value_loss           | 0.312      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.42        |
# |    ep_rew_mean          | 0.42        |
# | time/                   |             |
# |    fps                  | 298         |
# |    iterations           | 23          |
# |    time_elapsed         | 157         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.011185041 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.39       |
# |    explained_variance   | 0.0521      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.111       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0244     |
# |    value_loss           | 0.3         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.62        |
# |    ep_rew_mean          | 0.39        |
# | time/                   |             |
# |    fps                  | 301         |
# |    iterations           | 24          |
# |    time_elapsed         | 163         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.010406679 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.33       |
# |    explained_variance   | 0.0482      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.161       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0228     |
# |    value_loss           | 0.295       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.81        |
# |    ep_rew_mean          | 0.65        |
# | time/                   |             |
# |    fps                  | 304         |
# |    iterations           | 25          |
# |    time_elapsed         | 168         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.012407118 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.27       |
# |    explained_variance   | 0.0333      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.115       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0262     |
# |    value_loss           | 0.303       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.73        |
# |    ep_rew_mean          | 0.43        |
# | time/                   |             |
# |    fps                  | 307         |
# |    iterations           | 26          |
# |    time_elapsed         | 173         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.012298547 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.24       |
# |    explained_variance   | 0.0448      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0702      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0278     |
# |    value_loss           | 0.286       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.87       |
# |    ep_rew_mean          | 0.56       |
# | time/                   |            |
# |    fps                  | 310        |
# |    iterations           | 27         |
# |    time_elapsed         | 178        |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.01247162 |
# |    clip_fraction        | 0.136      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -9.17      |
# |    explained_variance   | 0.0381     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.122      |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.0272    |
# |    value_loss           | 0.291      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.73        |
# |    ep_rew_mean          | 0.37        |
# | time/                   |             |
# |    fps                  | 312         |
# |    iterations           | 28          |
# |    time_elapsed         | 183         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.012114438 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.12       |
# |    explained_variance   | 0.0552      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.166       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0277     |
# |    value_loss           | 0.311       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.78        |
# |    ep_rew_mean          | 0.41        |
# | time/                   |             |
# |    fps                  | 315         |
# |    iterations           | 29          |
# |    time_elapsed         | 188         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.012467318 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.98       |
# |    explained_variance   | 0.0367      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0762      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0274     |
# |    value_loss           | 0.272       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.13        |
# |    ep_rew_mean          | 0.53        |
# | time/                   |             |
# |    fps                  | 316         |
# |    iterations           | 30          |
# |    time_elapsed         | 194         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.012632387 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.89       |
# |    explained_variance   | 0.0393      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.119       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0266     |
# |    value_loss           | 0.31        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.24        |
# |    ep_rew_mean          | 0.73        |
# | time/                   |             |
# |    fps                  | 317         |
# |    iterations           | 31          |
# |    time_elapsed         | 200         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.011669155 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.82       |
# |    explained_variance   | 0.0505      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.118       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.026      |
# |    value_loss           | 0.317       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.22        |
# |    ep_rew_mean          | 0.58        |
# | time/                   |             |
# |    fps                  | 319         |
# |    iterations           | 32          |
# |    time_elapsed         | 205         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.012014904 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.76       |
# |    explained_variance   | 0.0679      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.103       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0271     |
# |    value_loss           | 0.367       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.17        |
# |    ep_rew_mean          | 0.56        |
# | time/                   |             |
# |    fps                  | 321         |
# |    iterations           | 33          |
# |    time_elapsed         | 210         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.011332722 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.74       |
# |    explained_variance   | 0.0738      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.14        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0277     |
# |    value_loss           | 0.325       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.29        |
# |    ep_rew_mean          | 0.64        |
# | time/                   |             |
# |    fps                  | 323         |
# |    iterations           | 34          |
# |    time_elapsed         | 214         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.012774784 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.64       |
# |    explained_variance   | 0.064       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.138       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0263     |
# |    value_loss           | 0.294       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.33        |
# |    ep_rew_mean          | 0.66        |
# | time/                   |             |
# |    fps                  | 326         |
# |    iterations           | 35          |
# |    time_elapsed         | 219         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.013224058 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.58       |
# |    explained_variance   | 0.0325      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.114       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0287     |
# |    value_loss           | 0.337       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.2         |
# |    ep_rew_mean          | 0.41        |
# | time/                   |             |
# |    fps                  | 328         |
# |    iterations           | 36          |
# |    time_elapsed         | 224         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.011764266 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.53       |
# |    explained_variance   | 0.0736      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.152       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0283     |
# |    value_loss           | 0.346       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.48        |
# |    ep_rew_mean          | 0.64        |
# | time/                   |             |
# |    fps                  | 331         |
# |    iterations           | 37          |
# |    time_elapsed         | 228         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.013094857 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.42       |
# |    explained_variance   | 0.0713      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.201       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0296     |
# |    value_loss           | 0.357       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.43         |
# |    ep_rew_mean          | 0.55         |
# | time/                   |              |
# |    fps                  | 333          |
# |    iterations           | 38           |
# |    time_elapsed         | 233          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0129452795 |
# |    clip_fraction        | 0.132        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -8.33        |
# |    explained_variance   | 0.0469       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.148        |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.0281      |
# |    value_loss           | 0.373        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.7          |
# |    ep_rew_mean          | 0.65         |
# | time/                   |              |
# |    fps                  | 335          |
# |    iterations           | 39           |
# |    time_elapsed         | 237          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0140634775 |
# |    clip_fraction        | 0.17         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -8.26        |
# |    explained_variance   | 0.0547       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.258        |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.0294      |
# |    value_loss           | 0.409        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.33        |
# |    ep_rew_mean          | 0.61        |
# | time/                   |             |
# |    fps                  | 337         |
# |    iterations           | 40          |
# |    time_elapsed         | 242         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.012377324 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.13       |
# |    explained_variance   | 0.0532      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.173       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0289     |
# |    value_loss           | 0.425       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.88        |
# |    ep_rew_mean          | 0.61        |
# | time/                   |             |
# |    fps                  | 340         |
# |    iterations           | 41          |
# |    time_elapsed         | 246         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.013709974 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.02       |
# |    explained_variance   | 0.0726      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.229       |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0304     |
# |    value_loss           | 0.37        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.55         |
# |    ep_rew_mean          | 0.65         |
# | time/                   |              |
# |    fps                  | 342          |
# |    iterations           | 42           |
# |    time_elapsed         | 251          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0125042815 |
# |    clip_fraction        | 0.136        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.94        |
# |    explained_variance   | 0.0783       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.149        |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.0284      |
# |    value_loss           | 0.363        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.42        |
# |    ep_rew_mean          | 0.71        |
# | time/                   |             |
# |    fps                  | 344         |
# |    iterations           | 43          |
# |    time_elapsed         | 255         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.013550479 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.77       |
# |    explained_variance   | 0.071       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.165       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0297     |
# |    value_loss           | 0.399       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.85        |
# |    ep_rew_mean          | 0.78        |
# | time/                   |             |
# |    fps                  | 347         |
# |    iterations           | 44          |
# |    time_elapsed         | 259         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.012936791 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.68       |
# |    explained_variance   | 0.0609      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0941      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0297     |
# |    value_loss           | 0.343       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.85       |
# |    ep_rew_mean          | 0.68       |
# | time/                   |            |
# |    fps                  | 349        |
# |    iterations           | 45         |
# |    time_elapsed         | 263        |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.01325412 |
# |    clip_fraction        | 0.15       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.59      |
# |    explained_variance   | 0.0858     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.098      |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.0305    |
# |    value_loss           | 0.402      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.2         |
# |    ep_rew_mean          | 0.86        |
# | time/                   |             |
# |    fps                  | 351         |
# |    iterations           | 46          |
# |    time_elapsed         | 267         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.013142575 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.45       |
# |    explained_variance   | 0.0972      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.187       |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0302     |
# |    value_loss           | 0.405       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.13        |
# |    ep_rew_mean          | 0.79        |
# | time/                   |             |
# |    fps                  | 353         |
# |    iterations           | 47          |
# |    time_elapsed         | 271         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.013032198 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.32       |
# |    explained_variance   | 0.0951      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.228       |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0268     |
# |    value_loss           | 0.449       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.19        |
# |    ep_rew_mean          | 0.84        |
# | time/                   |             |
# |    fps                  | 356         |
# |    iterations           | 48          |
# |    time_elapsed         | 276         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.015446398 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.12       |
# |    explained_variance   | 0.0913      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.209       |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0342     |
# |    value_loss           | 0.414       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.3         |
# |    ep_rew_mean          | 0.86        |
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 49          |
# |    time_elapsed         | 280         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.016757311 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.99       |
# |    explained_variance   | 0.0624      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.318       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0359     |
# |    value_loss           | 0.504       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.4         |
# |    ep_rew_mean          | 0.89        |
# | time/                   |             |
# |    fps                  | 360         |
# |    iterations           | 50          |
# |    time_elapsed         | 284         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.015630614 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.9        |
# |    explained_variance   | 0.114       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.181       |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0338     |
# |    value_loss           | 0.46        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.41         |
# |    ep_rew_mean          | 0.97         |
# | time/                   |              |
# |    fps                  | 361          |
# |    iterations           | 51           |
# |    time_elapsed         | 288          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0155095905 |
# |    clip_fraction        | 0.177        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.81        |
# |    explained_variance   | 0.105        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.254        |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.0353      |
# |    value_loss           | 0.452        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.26        |
# |    ep_rew_mean          | 1.06        |
# | time/                   |             |
# |    fps                  | 363         |
# |    iterations           | 52          |
# |    time_elapsed         | 292         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.015668904 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.65       |
# |    explained_variance   | 0.0982      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.18        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0367     |
# |    value_loss           | 0.524       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.29        |
# |    ep_rew_mean          | 0.96        |
# | time/                   |             |
# |    fps                  | 365         |
# |    iterations           | 53          |
# |    time_elapsed         | 296         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.017197648 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.45       |
# |    explained_variance   | 0.118       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.18        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0342     |
# |    value_loss           | 0.491       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.45        |
# |    ep_rew_mean          | 1.07        |
# | time/                   |             |
# |    fps                  | 367         |
# |    iterations           | 54          |
# |    time_elapsed         | 300         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.014477314 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.3        |
# |    explained_variance   | 0.117       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.167       |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.0367     |
# |    value_loss           | 0.574       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.88        |
# |    ep_rew_mean          | 1.36        |
# | time/                   |             |
# |    fps                  | 369         |
# |    iterations           | 55          |
# |    time_elapsed         | 304         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.015781822 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.09       |
# |    explained_variance   | 0.122       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.227       |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.0355     |
# ...
# | time/                   |             |
# |    fps                  | 399         |
# |    iterations           | 69          |
# |    time_elapsed         | 353         |
# |    total_timesteps      | 141312      |
# | train/                  |             |
# |    approx_kl            | 0.011166965 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.97       |
# |    explained_variance   | 0.0887      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.74        |
# |    n_updates            | 680         |
# |    policy_gradient_loss | -0.0337     |
# |    value_loss           | 12.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12.8        |
# |    ep_rew_mean          | 10.6        |
# | time/                   |             |
# |    fps                  | 402         |
# |    iterations           | 70          |
# |    time_elapsed         | 356         |
# |    total_timesteps      | 143360      |
# | train/                  |             |
# |    approx_kl            | 0.008942472 |
# |    clip_fraction        | 0.0792      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.77       |
# |    explained_variance   | 0.0434      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.7        |
# |    n_updates            | 690         |
# |    policy_gradient_loss | -0.0268     |
# |    value_loss           | 20.4        |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 15.1     |
# |    ep_rew_mean          | 12.9     |
# | time/                   |          |
# |    fps                  | 404      |
# |    iterations           | 71       |
# |    time_elapsed         | 359      |
# |    total_timesteps      | 145408   |
# | train/                  |          |
# |    approx_kl            | 0.006809 |
# |    clip_fraction        | 0.0685   |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -1.46    |
# |    explained_variance   | 0.0588   |
# |    learning_rate        | 0.0003   |
# |    loss                 | 12.4     |
# |    n_updates            | 700      |
# |    policy_gradient_loss | -0.024   |
# |    value_loss           | 24.1     |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 19.4        |
# |    ep_rew_mean          | 17          |
# | time/                   |             |
# |    fps                  | 407         |
# |    iterations           | 72          |
# |    time_elapsed         | 361         |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.004371397 |
# |    clip_fraction        | 0.0566      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.0418      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.6        |
# |    n_updates            | 710         |
# |    policy_gradient_loss | -0.019      |
# |    value_loss           | 31.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 23.6         |
# |    ep_rew_mean          | 21.5         |
# | time/                   |              |
# |    fps                  | 410          |
# |    iterations           | 73           |
# |    time_elapsed         | 364          |
# |    total_timesteps      | 149504       |
# | train/                  |              |
# |    approx_kl            | 0.0035015577 |
# |    clip_fraction        | 0.0423       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.0355       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.4         |
# |    n_updates            | 720          |
# |    policy_gradient_loss | -0.0171      |
# |    value_loss           | 42.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 24.5         |
# |    ep_rew_mean          | 22.4         |
# | time/                   |              |
# |    fps                  | 412          |
# |    iterations           | 74           |
# |    time_elapsed         | 367          |
# |    total_timesteps      | 151552       |
# | train/                  |              |
# |    approx_kl            | 0.0029959092 |
# |    clip_fraction        | 0.0322       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.83        |
# |    explained_variance   | 0.0327       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 29           |
# |    n_updates            | 730          |
# |    policy_gradient_loss | -0.0143      |
# |    value_loss           | 55.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 32.8        |
# |    ep_rew_mean          | 30.8        |
# | time/                   |             |
# |    fps                  | 415         |
# |    iterations           | 75          |
# |    time_elapsed         | 369         |
# |    total_timesteps      | 153600      |
# | train/                  |             |
# |    approx_kl            | 0.004217762 |
# |    clip_fraction        | 0.0385      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.8        |
# |    explained_variance   | 0.0339      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.7        |
# |    n_updates            | 740         |
# |    policy_gradient_loss | -0.0165     |
# |    value_loss           | 61.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 40.2         |
# |    ep_rew_mean          | 38.1         |
# | time/                   |              |
# |    fps                  | 418          |
# |    iterations           | 76           |
# |    time_elapsed         | 372          |
# |    total_timesteps      | 155648       |
# | train/                  |              |
# |    approx_kl            | 0.0026554274 |
# |    clip_fraction        | 0.0267       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.526       |
# |    explained_variance   | 0.0166       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 27.4         |
# |    n_updates            | 750          |
# |    policy_gradient_loss | -0.0114      |
# |    value_loss           | 71.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 45.2         |
# |    ep_rew_mean          | 42.9         |
# | time/                   |              |
# |    fps                  | 420          |
# |    iterations           | 77           |
# |    time_elapsed         | 374          |
# |    total_timesteps      | 157696       |
# | train/                  |              |
# |    approx_kl            | 0.0018510087 |
# |    clip_fraction        | 0.0235       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.484       |
# |    explained_variance   | 0.018        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 50.7         |
# |    n_updates            | 760          |
# |    policy_gradient_loss | -0.0103      |
# |    value_loss           | 91.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50.4         |
# |    ep_rew_mean          | 47.9         |
# | time/                   |              |
# |    fps                  | 423          |
# |    iterations           | 78           |
# |    time_elapsed         | 377          |
# |    total_timesteps      | 159744       |
# | train/                  |              |
# |    approx_kl            | 0.0016407492 |
# |    clip_fraction        | 0.0211       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.436       |
# |    explained_variance   | 0.0123       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 52.6         |
# |    n_updates            | 770          |
# |    policy_gradient_loss | -0.00975     |
# |    value_loss           | 103          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 63.1         |
# |    ep_rew_mean          | 60.7         |
# | time/                   |              |
# |    fps                  | 426          |
# |    iterations           | 79           |
# |    time_elapsed         | 379          |
# |    total_timesteps      | 161792       |
# | train/                  |              |
# |    approx_kl            | 0.0023602715 |
# |    clip_fraction        | 0.0231       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.422       |
# |    explained_variance   | 0.000941     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 54.9         |
# |    n_updates            | 780          |
# |    policy_gradient_loss | -0.00867     |
# |    value_loss           | 115          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 75.6          |
# |    ep_rew_mean          | 73.1          |
# | time/                   |               |
# |    fps                  | 428           |
# |    iterations           | 80            |
# |    time_elapsed         | 382           |
# |    total_timesteps      | 163840        |
# | train/                  |               |
# |    approx_kl            | 0.00042284495 |
# |    clip_fraction        | 0.00376       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.21         |
# |    explained_variance   | 0.00142       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 46.1          |
# |    n_updates            | 790           |
# |    policy_gradient_loss | -0.00307      |
# |    value_loss           | 89.9          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 91.2         |
# |    ep_rew_mean          | 88.8         |
# | time/                   |              |
# |    fps                  | 431          |
# |    iterations           | 81           |
# |    time_elapsed         | 384          |
# |    total_timesteps      | 165888       |
# | train/                  |              |
# |    approx_kl            | 0.0021338724 |
# |    clip_fraction        | 0.0188       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.241       |
# |    explained_variance   | 0.000491     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 89.5         |
# |    n_updates            | 800          |
# |    policy_gradient_loss | -0.00653     |
# |    value_loss           | 146          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 101          |
# |    ep_rew_mean          | 99           |
# | time/                   |              |
# |    fps                  | 433          |
# |    iterations           | 82           |
# |    time_elapsed         | 387          |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0022732425 |
# |    clip_fraction        | 0.00596      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.119       |
# |    explained_variance   | 0.000291     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23.1         |
# |    n_updates            | 810          |
# |    policy_gradient_loss | -0.00283     |
# |    value_loss           | 102          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 117          |
# |    ep_rew_mean          | 115          |
# | time/                   |              |
# |    fps                  | 436          |
# |    iterations           | 83           |
# |    time_elapsed         | 389          |
# |    total_timesteps      | 169984       |
# | train/                  |              |
# |    approx_kl            | 0.0020981168 |
# |    clip_fraction        | 0.016        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.164       |
# |    explained_variance   | 0.000471     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.8         |
# |    n_updates            | 820          |
# |    policy_gradient_loss | -0.0048      |
# |    value_loss           | 148          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 129          |
# |    ep_rew_mean          | 127          |
# | time/                   |              |
# |    fps                  | 439          |
# |    iterations           | 84           |
# |    time_elapsed         | 391          |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 0.0005665359 |
# |    clip_fraction        | 0.0042       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.108       |
# |    explained_variance   | 0.00154      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 75.6         |
# |    n_updates            | 830          |
# |    policy_gradient_loss | -0.00356     |
# |    value_loss           | 97.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 147          |
# |    ep_rew_mean          | 145          |
# | time/                   |              |
# |    fps                  | 441          |
# |    iterations           | 85           |
# |    time_elapsed         | 394          |
# |    total_timesteps      | 174080       |
# | train/                  |              |
# |    approx_kl            | 0.0018664093 |
# |    clip_fraction        | 0.00513      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0839      |
# |    explained_variance   | 0.000472     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 40.6         |
# |    n_updates            | 840          |
# |    policy_gradient_loss | -0.00286     |
# |    value_loss           | 85.7         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 166           |
# |    ep_rew_mean          | 164           |
# | time/                   |               |
# |    fps                  | 444           |
# |    iterations           | 86            |
# |    time_elapsed         | 396           |
# |    total_timesteps      | 176128        |
# | train/                  |               |
# |    approx_kl            | 0.00055070955 |
# |    clip_fraction        | 0.00352       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0918       |
# |    explained_variance   | 0.000334      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 37.5          |
# |    n_updates            | 850           |
# |    policy_gradient_loss | -0.00205      |
# |    value_loss           | 86            |
# -------------------------------------------

# %%
#Generate primes

env = PrimeEnv()
for ep in range(100):
    s, _ = env.reset()
    print("Starting number: {}".format(binatodeci(s)))
    done = False
    while not done:
        a = model.predict(s, deterministic=True)[0]
        s, r, done, _, _ = env.step(a)
        print("Next number predicted: {}".format(binatodeci(s)))
        print("Is prime: {}".format(bool(r)))
# Out:
# Starting number: 12529
# Next number predicted: 20341.0
# Is prime: True
# Next number predicted: 32911.0
# Is prime: True
# Next number predicted: 41077.0
# Is prime: True
# Next number predicted: 41333.0
# Is prime: True
# Next number predicted: 41809.0
# Is prime: True
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 4389
# Next number predicted: 20341.0
# Is prime: True
# Next number predicted: 32911.0
# Is prime: True
# Next number predicted: 41077.0
# Is prime: True
# Next number predicted: 41333.0
# Is prime: True
# Next number predicted: 41809.0
# Is prime: True
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 23839
# Next number predicted: 32911.0
# Is prime: True
# Next number predicted: 41077.0
# Is prime: True
# Next number predicted: 41333.0
# Is prime: True
# Next number predicted: 41809.0
# Is prime: True
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 35260
# Next number predicted: 41077.0
# Is prime: True
# Next number predicted: 41333.0
# Is prime: True
# Next number predicted: 41809.0
# Is prime: True
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 22716
# Next number predicted: 32911.0
# Is prime: True
# Next number predicted: 41077.0
# Is prime: True
# Next number predicted: 41333.0
# Is prime: True
# Next number predicted: 41809.0
# Is prime: True
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 5835
# Next number predicted: 20341.0
# Is prime: True
# Next number predicted: 32911.0
# Is prime: True
# Next number predicted: 41077.0
# Is prime: True
# Next number predicted: 41333.0
# Is prime: True
# Next number predicted: 41809.0
# Is prime: True
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 3653
# Next number predicted: 17909.0
# Is prime: True
# Next number predicted: 32911.0
# Is prime: True
# Next number predicted: 41077.0
# Is prime: True
# Next number predicted: 41333.0
# Is prime: True
# Next number predicted: 41809.0
# Is prime: True
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 57482
# Next number predicted: 61455.0
# Is prime: False
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 22581
# Next number predicted: 32909.0
# Is prime: True
# Next number predicted: 41077.0
# Is prime: True
# Next number predicted: 41333.0
# Is prime: True
# Next number predicted: 41809.0
# Is prime: True
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 34053
# Next number predicted: 41077.0
# Is prime: True
# Next number predicted: 41333.0
# Is prime: True
# Next number predicted: 41809.0
# Is prime: True
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 52894
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 16786
# Next number predicted: 32911.0
# Is prime: True
# Next number predicted: 41077.0
# Is prime: True
# Next number predicted: 41333.0
# Is prime: True
# Next number predicted: 41809.0
# Is prime: True
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 25893
# Next number predicted: 32909.0
# Is prime: True
# Next number predicted: 41077.0
# Is prime: True
# Next number predicted: 41333.0
# Is prime: True
# Next number predicted: 41809.0
# Is prime: True
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 62704
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 58494
# Next number predicted: 61455.0
# Is prime: False
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 52866
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 49832
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 49977
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 43742
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 36681
# Next number predicted: 41077.0
# Is prime: True
# Next number predicted: 41333.0
# Is prime: True
# Next number predicted: 41809.0
# Is prime: True
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 62622
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 10835
# Next number predicted: 20341.0
# Is prime: True
# Next number predicted: 32911.0
# Is prime: True
# Next number predicted: 41077.0
# Is prime: True
# Next number predicted: 41333.0
# Is prime: True
# Next number predicted: 41809.0
# Is prime: True
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 2508
# Next number predicted: 18421.0
# Is prime: False
# Next number predicted: 32911.0
# Is prime: True
# Next number predicted: 41077.0
# Is prime: True
# Next number predicted: 41333.0
# Is prime: True
# Next number predicted: 41809.0
# Is prime: True
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 62999
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 2031
# Next number predicted: 17909.0
# Is prime: True
# Next number predicted: 32911.0
# Is prime: True
# Next number predicted: 41077.0
# Is prime: True
# Next number predicted: 41333.0
# Is prime: True
# Next number predicted: 41809.0
# Is prime: True
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 44245
# Next number predicted: 50549.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 42624
# Next number predicted: 57173.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 56004
# Next number predicted: 64037.0
# Is prime: True
# Next number predicted: 65029.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 8571
# Next number predicted: 20341.0
# Is prime: True
# Next number predicted: 32911.0
# Is prime: True
# Next number predicted: 41077.0
# Is prime: True
# Next number predicted: 41333.0
# Is prime: True
# Next number predicted: 41809.0
# Is prime: True
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 47842
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 50335
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 47989
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 28479
# Next number predicted: 32911.0
# Is prime: True
# Next number predicted: 41077.0
# Is prime: True
# Next number predicted: 41333.0
# Is prime: True
# Next number predicted: 41809.0
# Is prime: True
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 39974
# Next number predicted: 41333.0
# Is prime: True
# Next number predicted: 41809.0
# Is prime: True
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 7231
# Next number predicted: 20341.0
# Is prime: True
# Next number predicted: 32911.0
# Is prime: True
# Next number predicted: 41077.0
# Is prime: True
# Next number predicted: 41333.0
# Is prime: True
# Next number predicted: 41809.0
# Is prime: True
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 45702
# Next number predicted: 55157.0
# Is prime: False
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 54518
# Next number predicted: 61453.0
# Is prime: False
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 64308
# Next number predicted: 65027.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 27444
# Next number predicted: 53387.0
# Is prime: False
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 28118
# Next number predicted: 32911.0
# Is prime: True
# Next number predicted: 41077.0
# Is prime: True
# Next number predicted: 41333.0
# Is prime: True
# Next number predicted: 41809.0
# Is prime: True
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 7306
# Next number predicted: 20341.0
# Is prime: True
# Next number predicted: 32911.0
# Is prime: True
# Next number predicted: 41077.0
# Is prime: True
# Next number predicted: 41333.0
# Is prime: True
# Next number predicted: 41809.0
# Is prime: True
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 11078
# Next number predicted: 20343.0
# Is prime: False
# Next number predicted: 32911.0
# Is prime: True
# Next number predicted: 41077.0
# Is prime: True
# Next number predicted: 41333.0
# Is prime: True
# Next number predicted: 41809.0
# Is prime: True
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 30254
# Next number predicted: 32909.0
# Is prime: True
# Next number predicted: 41077.0
# Is prime: True
# Next number predicted: 41333.0
# Is prime: True
# Next number predicted: 41809.0
# Is prime: True
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 48462
# Next number predicted: 55153.0
# Is prime: False
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 8349
# Next number predicted: 20341.0
# Is prime: True
# Next number predicted: 32911.0
# Is prime: True
# Next number predicted: 41077.0
# Is prime: True
# Next number predicted: 41333.0
# Is prime: True
# Next number predicted: 41809.0
# Is prime: True
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 36013
# Next number predicted: 41077.0
# Is prime: True
# Next number predicted: 41333.0
# Is prime: True
# Next number predicted: 41809.0
# Is prime: True
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 19573
# Next number predicted: 32911.0
# Is prime: True
# Next number predicted: 41077.0
# Is prime: True
# Next number predicted: 41333.0
# Is prime: True
# Next number predicted: 41809.0
# Is prime: True
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 59334
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 56766
# Next number predicted: 61981.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 65079
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 54070
# Next number predicted: 61981.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 50592
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 47201
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 45239
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 4027
# Next number predicted: 17909.0
# Is prime: True
# Next number predicted: 32911.0
# Is prime: True
# Next number predicted: 41077.0
# Is prime: True
# Next number predicted: 41333.0
# Is prime: True
# Next number predicted: 41809.0
# Is prime: True
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 61957
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 29264
# Next number predicted: 39567.0
# Is prime: False
# Next number predicted: 41077.0
# Is prime: True
# Next number predicted: 41333.0
# Is prime: True
# Next number predicted: 41809.0
# Is prime: True
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 38591
# Next number predicted: 41077.0
# Is prime: True
# Next number predicted: 41333.0
# Is prime: True
# Next number predicted: 41809.0
# Is prime: True
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 15420
# Next number predicted: 20341.0
# Is prime: True
# Next number predicted: 32911.0
# Is prime: True
# Next number predicted: 41077.0
# Is prime: True
# Next number predicted: 41333.0
# Is prime: True
# Next number predicted: 41809.0
# Is prime: True
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 36778
# Next number predicted: 59253.0
# Is prime: False
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 41984
# Next number predicted: 65397.0
# Is prime: False
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 13484
# Next number predicted: 20341.0
# Is prime: True
# Next number predicted: 32911.0
# Is prime: True
# Next number predicted: 41077.0
# Is prime: True
# Next number predicted: 41333.0
# Is prime: True
# Next number predicted: 41809.0
# Is prime: True
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 52146
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 16972
# Next number predicted: 45199.0
# Is prime: False
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 45688
# Next number predicted: 57205.0
# Is prime: False
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 14480
# Next number predicted: 20341.0
# Is prime: True
# Next number predicted: 32911.0
# Is prime: True
# Next number predicted: 41077.0
# Is prime: True
# Next number predicted: 41333.0
# Is prime: True
# Next number predicted: 41809.0
# Is prime: True
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 50177
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 63036
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# ...
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 33941
# Next number predicted: 41077.0
# Is prime: True
# Next number predicted: 41333.0
# Is prime: True
# Next number predicted: 41809.0
# Is prime: True
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 64568
# Next number predicted: 65039.0
# Is prime: False
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 48609
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 42946
# Next number predicted: 55157.0
# Is prime: False
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 47003
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 53602
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 1070
# Next number predicted: 17909.0
# Is prime: True
# Next number predicted: 32911.0
# Is prime: True
# Next number predicted: 41077.0
# Is prime: True
# Next number predicted: 41333.0
# Is prime: True
# Next number predicted: 41809.0
# Is prime: True
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 56153
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 4505
# Next number predicted: 20341.0
# Is prime: True
# Next number predicted: 32911.0
# Is prime: True
# Next number predicted: 41077.0
# Is prime: True
# Next number predicted: 41333.0
# Is prime: True
# Next number predicted: 41809.0
# Is prime: True
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 14253
# Next number predicted: 20341.0
# Is prime: True
# Next number predicted: 32911.0
# Is prime: True
# Next number predicted: 41077.0
# Is prime: True
# Next number predicted: 41333.0
# Is prime: True
# Next number predicted: 41809.0
# Is prime: True
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 23176
# Next number predicted: 32911.0
# Is prime: True
# Next number predicted: 41077.0
# Is prime: True
# Next number predicted: 41333.0
# Is prime: True
# Next number predicted: 41809.0
# Is prime: True
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 56268
# Next number predicted: 64063.0
# Is prime: True
# Next number predicted: 65029.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 7229
# Next number predicted: 20341.0
# Is prime: True
# Next number predicted: 32911.0
# Is prime: True
# Next number predicted: 41077.0
# Is prime: True
# Next number predicted: 41333.0
# Is prime: True
# Next number predicted: 41809.0
# Is prime: True
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 46637
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 16231
# Next number predicted: 20341.0
# Is prime: True
# Next number predicted: 32911.0
# Is prime: True
# Next number predicted: 41077.0
# Is prime: True
# Next number predicted: 41333.0
# Is prime: True
# Next number predicted: 41809.0
# Is prime: True
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 17773
# Next number predicted: 32909.0
# Is prime: True
# Next number predicted: 41077.0
# Is prime: True
# Next number predicted: 41333.0
# Is prime: True
# Next number predicted: 41809.0
# Is prime: True
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 39683
# Next number predicted: 41077.0
# Is prime: True
# Next number predicted: 41333.0
# Is prime: True
# Next number predicted: 41809.0
# Is prime: True
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 56681
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 3304
# Next number predicted: 19957.0
# Is prime: False
# Next number predicted: 32911.0
# Is prime: True
# Next number predicted: 41077.0
# Is prime: True
# Next number predicted: 41333.0
# Is prime: True
# Next number predicted: 41809.0
# Is prime: True
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 34787
# Next number predicted: 41333.0
# Is prime: True
# Next number predicted: 41809.0
# Is prime: True
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
# Starting number: 12983
# Next number predicted: 20341.0
# Is prime: True
# Next number predicted: 32911.0
# Is prime: True
# Next number predicted: 41077.0
# Is prime: True
# Next number predicted: 41333.0
# Is prime: True
# Next number predicted: 41809.0
# Is prime: True
# Next number predicted: 51061.0
# Is prime: True
# Next number predicted: 57373.0
# Is prime: True
# Next number predicted: 61469.0
# Is prime: True
# Next number predicted: 61967.0
# Is prime: True
# Next number predicted: 64013.0
# Is prime: True
# Next number predicted: 65141.0
# Is prime: True
# Next number predicted: 65293.0
# Is prime: True
# Next number predicted: 65309.0
# Is prime: True
# Next number predicted: 65371.0
# Is prime: True
# Next number predicted: 65407.0
# Is prime: True
# Next number predicted: 65419.0
# Is prime: True
# Next number predicted: 65437.0
# Is prime: True
# Next number predicted: 65497.0
# Is prime: True
# Next number predicted: 65455.0
# Is prime: False
